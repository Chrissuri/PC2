# %% [markdown]
# <a href="https://colab.research.google.com/github/Chrissuri/PC2/blob/main/PC2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
linkGit= https://github.com/Chrissuri/PC2/raw/main/PC2.ipynb
dataRaee=pd.read_csv(linkGit)

# %%
humanLink="https://docs.google.com/spreadsheets/d/e/2PACX-1vSPVJIoDhupNyUpYD65FSHt6kMmF_KaxE2RD6CV1FOMP4vVw7WfKQMqpqo0ieD9vhMAmYP1NpBmw0od/pubhtml?gid=658985149&single=true"

#Observamos la lista de Dataframes

import pandas as pd

humanList=pd.read_html(humanLink,header=0,flavor='bs4')

#Obtenemos el DataFrame de la lista
human=humanList[0]

# %%
human
# Out:
#      Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0             1       Back  Table 1. Human Development Index and its compo...
# 1             2        NaN                                                NaN
# 2             3        NaN                                                NaN
# 3             4        NaN                                                NaN
# 4             5        NaN                                                NaN
# ..          ...        ...                                                ...
# 272         273        NaN                          Column 2: UNDESA (2022a).
# 273         274        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 274         275        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 275         276        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 276         277        NaN  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 3  Unnamed: 4                Unnamed: 5  \
# 0                              NaN         NaN                       NaN
# 1                              NaN         NaN                       NaN
# 2                              NaN         NaN                      SDG3
# 3                              NaN         NaN                       NaN
# 4    Human Development Index (HDI)         NaN  Life expectancy at birth
# ..                             ...         ...                       ...
# 272                            NaN         NaN                       NaN
# 273                            NaN         NaN                       NaN
# 274                            NaN         NaN                       NaN
# 275                            NaN         NaN                       NaN
# 276                            NaN         NaN                       NaN
#
#     Unnamed: 6                   Unnamed: 7 Unnamed: 8  \
# 0          NaN                          NaN        NaN
# 1          NaN                          NaN        NaN
# 2          NaN                       SDG4.3        NaN
# 3          NaN                          NaN        NaN
# 4          NaN  Expected years of schooling        NaN
# ..         ...                          ...        ...
# 272        NaN                          NaN        NaN
# 273        NaN                          NaN        NaN
# 274        NaN                          NaN        NaN
# 275        NaN                          NaN        NaN
# 276        NaN                          NaN        NaN
#
#                   Unnamed: 9 Unnamed: 10  \
# 0                        NaN         NaN
# 1                        NaN         NaN
# 2                     SDG4.4         NaN
# 3                        NaN         NaN
# 4    Mean years of schooling         NaN
# ..                       ...         ...
# 272                      NaN         NaN
# 273                      NaN         NaN
# 274                      NaN         NaN
# 275                      NaN         NaN
# 276                      NaN         NaN
#
#                                 Unnamed: 11 Unnamed: 12  \
# 0                                       NaN         NaN
# 1                                       NaN         NaN
# 2                                    SDG8.5         NaN
# 3                                       NaN         NaN
# 4    Gross national income (GNI) per capita         NaN
# ..                                      ...         ...
# 272                                     NaN         NaN
# 273                                     NaN         NaN
# 274                                     NaN         NaN
# 275                                     NaN         NaN
# 276                                     NaN         NaN
#
#                             Unnamed: 13 Unnamed: 14 Unnamed: 15
# 0                                   NaN         NaN         NaN
# 1                                   NaN         NaN         NaN
# 2                                   NaN         NaN         NaN
# 3                                   NaN         NaN         NaN
# 4    GNI per capita rank minus HDI rank         NaN    HDI rank
# ..                                  ...         ...         ...
# 272                                 NaN         NaN         NaN
# 273                                 NaN         NaN         NaN
# 274                                 NaN         NaN         NaN
# 275                                 NaN         NaN         NaN
# 276                                 NaN         NaN         NaN
#
# [277 rows x 16 columns]

# %% [markdown]
# LIMPIEZA

# %%
#renombre de columnas
newHumanNames={'Unnamed: 1':'HDI_rank','Unnamed: 2':'Country',"Unnamed: 3":"Value","Unnamed: 5":"Life_Expectancy","Unnamed: 7":"Exp_Years_School","Unnamed: 9":"Mean_Years_School","Unnamed: 11":"GNI_capita","Unnamed: 13":"GNI_HDI_RANK","Unnamed: 15":"HDI_RANK"}
human.rename(columns=newHumanNames,inplace=True)

# %%
human
# Out:
#      Unnamed: 0 HDI_rank                                            Country  \
# 0             1     Back  Table 1. Human Development Index and its compo...
# 1             2      NaN                                                NaN
# 2             3      NaN                                                NaN
# 3             4      NaN                                                NaN
# 4             5      NaN                                                NaN
# ..          ...      ...                                                ...
# 272         273      NaN                          Column 2: UNDESA (2022a).
# 273         274      NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 274         275      NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 275         276      NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 276         277      NaN  Column 6: Calculated based on data in columns ...
#
#                              Value  Unnamed: 4           Life_Expectancy  \
# 0                              NaN         NaN                       NaN
# 1                              NaN         NaN                       NaN
# 2                              NaN         NaN                      SDG3
# 3                              NaN         NaN                       NaN
# 4    Human Development Index (HDI)         NaN  Life expectancy at birth
# ..                             ...         ...                       ...
# 272                            NaN         NaN                       NaN
# 273                            NaN         NaN                       NaN
# 274                            NaN         NaN                       NaN
# 275                            NaN         NaN                       NaN
# 276                            NaN         NaN                       NaN
#
#     Unnamed: 6             Exp_Years_School Unnamed: 8  \
# 0          NaN                          NaN        NaN
# 1          NaN                          NaN        NaN
# 2          NaN                       SDG4.3        NaN
# 3          NaN                          NaN        NaN
# 4          NaN  Expected years of schooling        NaN
# ..         ...                          ...        ...
# 272        NaN                          NaN        NaN
# 273        NaN                          NaN        NaN
# 274        NaN                          NaN        NaN
# 275        NaN                          NaN        NaN
# 276        NaN                          NaN        NaN
#
#            Mean_Years_School Unnamed: 10  \
# 0                        NaN         NaN
# 1                        NaN         NaN
# 2                     SDG4.4         NaN
# 3                        NaN         NaN
# 4    Mean years of schooling         NaN
# ..                       ...         ...
# 272                      NaN         NaN
# 273                      NaN         NaN
# 274                      NaN         NaN
# 275                      NaN         NaN
# 276                      NaN         NaN
#
#                                  GNI_capita Unnamed: 12  \
# 0                                       NaN         NaN
# 1                                       NaN         NaN
# 2                                    SDG8.5         NaN
# 3                                       NaN         NaN
# 4    Gross national income (GNI) per capita         NaN
# ..                                      ...         ...
# 272                                     NaN         NaN
# 273                                     NaN         NaN
# 274                                     NaN         NaN
# 275                                     NaN         NaN
# 276                                     NaN         NaN
#
#                            GNI_HDI_RANK Unnamed: 14  HDI_RANK
# 0                                   NaN         NaN       NaN
# 1                                   NaN         NaN       NaN
# 2                                   NaN         NaN       NaN
# 3                                   NaN         NaN       NaN
# 4    GNI per capita rank minus HDI rank         NaN  HDI rank
# ..                                  ...         ...       ...
# 272                                 NaN         NaN       NaN
# 273                                 NaN         NaN       NaN
# 274                                 NaN         NaN       NaN
# 275                                 NaN         NaN       NaN
# 276                                 NaN         NaN       NaN
#
# [277 rows x 16 columns]

# %%
#quitar columnas
byeColumns=["Unnamed: 0","HDI_rank","Unnamed: 4","Unnamed: 6","Unnamed: 8","Unnamed: 10","Unnamed: 12","Unnamed: 14","GNI_HDI_RANK","HDI_RANK"]

human.drop(columns=byeColumns,inplace=True)

# %%
#muestra de las primeras 10 filas
human.head(10)
# Out:
#                                              Country  \
# 0  Table 1. Human Development Index and its compo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                            Country
# 6                                                NaN
# 7                        VERY HIGH HUMAN DEVELOPMENT
# 8                                        Switzerland
# 9                                             Norway
#
#                            Value           Life_Expectancy  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                      SDG3
# 3                            NaN                       NaN
# 4  Human Development Index (HDI)  Life expectancy at birth
# 5                          Value                   (years)
# 6                           2021                      2021
# 7                            NaN                       NaN
# 8                            962                      84.0
# 9                            961                      83.2
#
#               Exp_Years_School        Mean_Years_School  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                       SDG4.3                   SDG4.4
# 3                          NaN                      NaN
# 4  Expected years of schooling  Mean years of schooling
# 5                      (years)                  (years)
# 6                         2021                     2021
# 7                          NaN                      NaN
# 8                         16.5                     13.9
# 9                         18.2                     13.0
#
#                                GNI_capita
# 0                                     NaN
# 1                                     NaN
# 2                                  SDG8.5
# 3                                     NaN
# 4  Gross national income (GNI) per capita
# 5                            (2017 PPP $)
# 6                                    2021
# 7                                     NaN
# 8                                   66933
# 9                                   64660

# %%
#quitar filas
byeRows=[0,1,2,3,4,5,6,7,74,124,169]
human.drop(index=byeRows,inplace=True)

# %%
human
# Out:
#                                                Country Value Life_Expectancy  \
# 8                                          Switzerland   962            84.0
# 9                                               Norway   961            83.2
# 10                                             Iceland   959            82.7
# 11                              Hong Kong, China (SAR)   952            85.5
# 12                                           Australia   951            84.5
# ..                                                 ...   ...             ...
# 272                          Column 2: UNDESA (2022a).   NaN             NaN
# 273  Column 3: CEDLAS and World Bank (2022), ICF Ma...   NaN             NaN
# 274  Column 4: Barro and Lee (2018), ICF Macro Demo...   NaN             NaN
# 275  Column 5: IMF (2022), UNDESA (2022b), United N...   NaN             NaN
# 276  Column 6: Calculated based on data in columns ...   NaN             NaN
#
#     Exp_Years_School Mean_Years_School GNI_capita
# 8               16.5              13.9      66933
# 9               18.2              13.0      64660
# 10              19.2              13.8      55782
# 11              17.3              12.2      62607
# 12              21.1              12.7      49238
# ..               ...               ...        ...
# 272              NaN               NaN        NaN
# 273              NaN               NaN        NaN
# 274              NaN               NaN        NaN
# 275              NaN               NaN        NaN
# 276              NaN               NaN        NaN
#
# [266 rows x 6 columns]

# %%
#quitar un rango de filas
human=human.drop(range(202,277))

# %%
human
# Out:
#                       Country Value Life_Expectancy Exp_Years_School  \
# 8                 Switzerland   962            84.0             16.5
# 9                      Norway   961            83.2             18.2
# 10                    Iceland   959            82.7             19.2
# 11     Hong Kong, China (SAR)   952            85.5             17.3
# 12                  Australia   951            84.5             21.1
# ..                        ...   ...             ...              ...
# 197                   Burundi   426            61.7             10.7
# 198  Central African Republic   404            53.9              8.0
# 199                     Niger   400            61.6              7.0
# 200                      Chad   394            52.5              8.0
# 201               South Sudan   385            55.0              5.5
#
#     Mean_Years_School GNI_capita
# 8                13.9      66933
# 9                13.0      64660
# 10               13.8      55782
# 11               12.2      62607
# 12               12.7      49238
# ..                ...        ...
# 197               3.1        732
# 198               4.3        966
# 199               2.1       1240
# 200               2.6       1364
# 201               5.7        768
#
# [191 rows x 6 columns]

# %%
#ningun espacio en columnas
human.columns=human.columns.str.replace(r'\s','',regex=True)

# %%
#no spacios en string values (para varias columnas)
byeSpaces=lambda x: x.str.strip()
human.iloc[:,[0,5]]=human.iloc[:,[0,5]].apply(byeSpaces)

# %%
human.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 8 to 201
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            191 non-null    object
#  1   Value              191 non-null    object
#  2   Life_Expectancy    191 non-null    object
#  3   Exp_Years_School   191 non-null    object
#  4   Mean_Years_School  191 non-null    object
#  5   GNI_capita         191 non-null    object
# dtypes: object(6)
# memory usage: 10.4+ KB

# %% [markdown]
# FORMATEO

# %%
#tenemos duplicados?
human[human.duplicated(subset='Country')]
# Out:
# Empty DataFrame
# Columns: [Country, Value, Life_Expectancy, Exp_Years_School, Mean_Years_School, GNI_capita]
# Index: []

# %%
#Tenemos simbolos raros?
human[human.Country.str.contains(r'[^\w\s]')]
# Out:
#                                 Country Value Life_Expectancy  \
# 11               Hong Kong, China (SAR)   952            85.5
# 27                  Korea (Republic of)   925            83.7
# 84           Iran (Islamic Republic of)   774            73.9
# 89                Moldova (Republic of)   767            68.8
# 114                 Palestine, State of   715            73.5
# 127    Bolivia (Plurinational State of)   692            63.6
# 129  Venezuela (Bolivarian Republic of)   691            70.6
# 143    Micronesia (Federated States of)   628            70.7
# 149    Lao People's Democratic Republic   607            68.1
# 150                         Timor-Leste   607            67.7
# 153               Eswatini (Kingdom of)   597            57.1
# 168                       Côte d'Ivoire   550            58.6
# 170       Tanzania (United Republic of)   549            66.2
# 187                       Guinea-Bissau   483            59.7
# 189  Congo (Democratic Republic of the)   479            59.2
#
#     Exp_Years_School Mean_Years_School GNI_capita
# 11              17.3              12.2      62607
# 27              16.5              12.5      44501
# 84              14.6              10.6      13001
# 89              14.4              11.8      14875
# 114             13.4               9.9       6583
# 127             14.9               9.8       8111
# 129             12.8              11.1       4811
# 143             11.5               7.8       3696
# 149             10.1               5.4       7700
# 150             12.6               5.4       4461
# 153             13.7               5.6       7679
# 168             10.7               5.2       5217
# 170              9.2               6.4       2664
# 187             10.6               3.6       1908
# 189              9.8               7.0       1076

# %%
#Tenemos acentos en palabras?
human[human.Country.str.contains(r"\w*[\u00C0-\u01DA']\w*")]
# Out:
#                               Country Value Life_Expectancy Exp_Years_School  \
# 55                            Türkiye   838            76.0             18.3
# 149  Lao People's Democratic Republic   607            68.1             10.1
# 168                     Côte d'Ivoire   550            58.6             10.7
#
#     Mean_Years_School GNI_capita
# 55                8.6      31033
# 149               5.4       7700
# 168               5.2       5217

# %%
pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
#solo ascii
from unidecode import unidecode

human['Country']=human.Country.apply(unidecode)

# %%
#creamos una nueva columna con valores en mayuscula
human_test=human.copy()
human_test['COUNTRYNAME']=human_test.Country.str.upper()
human_test
# Out:
#                       Country Value Life_Expectancy Exp_Years_School  \
# 8                 Switzerland   962            84.0             16.5
# 9                      Norway   961            83.2             18.2
# 10                    Iceland   959            82.7             19.2
# 11     Hong Kong, China (SAR)   952            85.5             17.3
# 12                  Australia   951            84.5             21.1
# ..                        ...   ...             ...              ...
# 197                   Burundi   426            61.7             10.7
# 198  Central African Republic   404            53.9              8.0
# 199                     Niger   400            61.6              7.0
# 200                      Chad   394            52.5              8.0
# 201               South Sudan   385            55.0              5.5
#
#     Mean_Years_School GNI_capita               COUNTRYNAME
# 8                13.9      66933               SWITZERLAND
# 9                13.0      64660                    NORWAY
# 10               13.8      55782                   ICELAND
# 11               12.2      62607    HONG KONG, CHINA (SAR)
# 12               12.7      49238                 AUSTRALIA
# ..                ...        ...                       ...
# 197               3.1        732                   BURUNDI
# 198               4.3        966  CENTRAL AFRICAN REPUBLIC
# 199               2.1       1240                     NIGER
# 200               2.6       1364                      CHAD
# 201               5.7        768               SOUTH SUDAN
#
# [191 rows x 7 columns]

# %%
#Mantenmos los nombres en mayusculas
human['Country']=human.Country.str.upper()
human
# Out:
#                       Country Value Life_Expectancy Exp_Years_School  \
# 8                 SWITZERLAND   962            84.0             16.5
# 9                      NORWAY   961            83.2             18.2
# 10                    ICELAND   959            82.7             19.2
# 11     HONG KONG, CHINA (SAR)   952            85.5             17.3
# 12                  AUSTRALIA   951            84.5             21.1
# ..                        ...   ...             ...              ...
# 197                   BURUNDI   426            61.7             10.7
# 198  CENTRAL AFRICAN REPUBLIC   404            53.9              8.0
# 199                     NIGER   400            61.6              7.0
# 200                      CHAD   394            52.5              8.0
# 201               SOUTH SUDAN   385            55.0              5.5
#
#     Mean_Years_School GNI_capita
# 8                13.9      66933
# 9                13.0      64660
# 10               13.8      55782
# 11               12.2      62607
# 12               12.7      49238
# ..                ...        ...
# 197               3.1        732
# 198               4.3        966
# 199               2.1       1240
# 200               2.6       1364
# 201               5.7        768
#
# [191 rows x 6 columns]

# %%
human.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 8 to 201
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            191 non-null    object
#  1   Value              191 non-null    object
#  2   Life_Expectancy    191 non-null    object
#  3   Exp_Years_School   191 non-null    object
#  4   Mean_Years_School  191 non-null    object
#  5   GNI_capita         191 non-null    object
# dtypes: object(6)
# memory usage: 10.4+ KB

# %%
#Cambiamos los valores de las columnas a valores numericos

human['Value']=pd.to_numeric(human.Value)
human['Life_Expectancy']=pd.to_numeric(human.Life_Expectancy)
human['Exp_Years_School']=pd.to_numeric(human.Exp_Years_School)
human['Mean_Years_School']=pd.to_numeric(human.Mean_Years_School)
human['GNI_capita']=pd.to_numeric(human.GNI_capita)
human.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 8 to 201
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            191 non-null    object
#  1   Value              191 non-null    int64
#  2   Life_Expectancy    191 non-null    float64
#  3   Exp_Years_School   191 non-null    float64
#  4   Mean_Years_School  191 non-null    float64
#  5   GNI_capita         191 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 10.4+ KB

# %%
human
# Out:
#                       Country  Value  Life_Expectancy  Exp_Years_School  \
# 8                 SWITZERLAND    962             84.0              16.5
# 9                      NORWAY    961             83.2              18.2
# 10                    ICELAND    959             82.7              19.2
# 11     HONG KONG, CHINA (SAR)    952             85.5              17.3
# 12                  AUSTRALIA    951             84.5              21.1
# ..                        ...    ...              ...               ...
# 197                   BURUNDI    426             61.7              10.7
# 198  CENTRAL AFRICAN REPUBLIC    404             53.9               8.0
# 199                     NIGER    400             61.6               7.0
# 200                      CHAD    394             52.5               8.0
# 201               SOUTH SUDAN    385             55.0               5.5
#
#      Mean_Years_School  GNI_capita
# 8                 13.9       66933
# 9                 13.0       64660
# 10                13.8       55782
# 11                12.2       62607
# 12                12.7       49238
# ..                 ...         ...
# 197                3.1         732
# 198                4.3         966
# 199                2.1        1240
# 200                2.6        1364
# 201                5.7         768
#
# [191 rows x 6 columns]

# %% [markdown]
# |
